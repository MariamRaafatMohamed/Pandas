# %% [markdown]
# <a href="https://colab.research.google.com/github/MariamRaafatMohamed/Pandas/blob/main/Exercises_(15).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv")
tips.head(5)
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop(columns=["Unnamed: 0"], inplace=True)

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
tips['total_bill'].hist(bins=20)
plt.title('Histogram of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
plt.scatter(tips['total_bill'], tips['tip'])
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='size', fit_reg=False)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.scatterplot(x='tip', y='day', hue='sex', data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x='day', y='total_bill', hue='time', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
sns.set_style("whitegrid")

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

sns.histplot(data=tips[tips['time'] == 'Dinner'], x='tip', ax=axes[0], kde=False, color='skyblue')
axes[0].set_title('Dinner Tips')

sns.histplot(data=tips[tips['time'] == 'Lunch'], x='tip', ax=axes[1], kde=False, color='salmon')
axes[1].set_title('Lunch Tips')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
ig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

sns.scatterplot(
    data=tips[tips['sex'] == 'Male'],
    x='total_bill',
    y='tip',
    hue='smoker',
    ax=axes[0]
)
axes[0].set_title('Male: Tip vs Total Bill')

sns.scatterplot(
    data=tips[tips['sex'] == 'Female'],
    x='total_bill',
    y='tip',
    hue='smoker',
    ax=axes[1]
)
axes[1].set_title('Female: Tip vs Total Bill')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=tips, x='day', y='tip', hue='smoker')
plt.title('Average Tip by Day and Smoking Status')
plt.ylabel('Average Tip')
plt.xlabel('Day of the Week')
plt.show()
